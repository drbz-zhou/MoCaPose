# %%
import json
from google.colab import drive
drive.mount('/content/drive')

sync_dict_train = {
  "Record_Name": ["David_R1", "Daniel_R1"],
  "Date": ["02/06","02/06"],
  #Check in Matlab plot the last pulse in the capacitive data due to touching the faceshield at the START of the recording.
  "Cap_Init_Touch": [1677,2],
  #Check in Matlab plot the last pulse in the capacitive data due to touching the faceshield at the END of the recording.
  "Cap_End_Touch": [7369,2],
  #Check in the video the second in which the hand touches the faceshield for the last time during the the START of the recording.
  "Video_Init_Touch": [5,2], #in seconds
  #Check in the video the second in which the hand touches the faceshield for the last time during the the END of the recording.
  "Video_End_Touch": [605,2] #in seconds
}

jsonString = json.dumps(sync_dict_train)
jsonFile = open("/content/drive/MyDrive/Regressor/Recording_JSON/Recordings_Train.json", "w")
jsonFile.write(jsonString)
jsonFile.close()

sync_dict_train = {
  "Record_Name": ["David_R1", "Daniel_R1"],
  "Date": ["02/06","02/06"],
  #Check in Matlab plot the last pulse in the capacitive data due to touching the faceshield at the START of the recording.
  "Cap_Init_Touch": [1677,2],
  #Check in Matlab plot the last pulse in the capacitive data due to touching the faceshield at the END of the recording.
  "Cap_End_Touch": [7369,2],
  #Check in the video the second in which the hand touches the faceshield for the last time during the the START of the recording.
  "Video_Init_Touch": [5,2], #in seconds
  #Check in the video the second in which the hand touches the faceshield for the last time during the the END of the recording.
  "Video_End_Touch": [605,2] #in seconds
}

jsonString = json.dumps(sync_dict_train)
jsonFile = open("/content/drive/MyDrive/Regressor/Recording_JSON/Recordings_Test.json", "w")
jsonFile.write(jsonString)
jsonFile.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
